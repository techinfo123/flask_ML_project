# %%
import pandas as pd 

import joblib 

import sklearn

# %%
import numpy as np

# %%
! pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
pip install numpy==1.25.0
# Out:
# Collecting numpy==1.25.0
#   Using cached numpy-1.25.0-cp311-cp311-win_amd64.whl.metadata (5.7 kB)
# Using cached numpy-1.25.0-cp311-cp311-win_amd64.whl (15.0 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.2
#     Uninstalling numpy-2.2.2:
#       Successfully uninstalled numpy-2.2.2
# Successfully installed numpy-1.25.0
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Atishay\AppData\Local\Programs\Python\Python311\Lib\site-packages\~umpy.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Atishay\AppData\Local\Programs\Python\Python311\Lib\site-packages\~umpy'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: C:\Users\Atishay\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
pip install --upgrade matplotlib seaborn
# Out:
# Requirement already satisfied: matplotlib in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (3.7.1)
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: seaborn in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=8 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached matplotlib-3.10.1-cp311-cp311-win_amd64.whl (8.1 MB)
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.1
#     Uninstalling matplotlib-3.7.1:
#       Successfully uninstalled matplotlib-3.7.1
# Successfully installed matplotlib-3.10.1
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Atishay\AppData\Local\Programs\Python\Python311\Lib\site-packages\~atplotlib.libs'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\Atishay\AppData\Local\Programs\Python\Python311\Lib\site-packages\~atplotlib'.
#   You can safely remove it manually.
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: C:\Users\Atishay\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip

# %%
import pip
pip.main(['install', '--upgrade', 'pip'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: pip in c:\users\atishay\appdata\local\programs\python\python311\lib\site-packages (25.0)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
# C:\Users\Atishay\AppData\Local\Programs\Python\Python311\Lib\site-packages\pip\_vendor\rich\live.py:231:
# UserWarning: install "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.0
#     Uninstalling pip-25.0:
#       Successfully uninstalled pip-25.0
# Successfully installed pip-25.0.1
# 0

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.6-py3-none-any.whl.metadata (2.4 kB)
# Collecting comm>=0.1.3 (from ipywidgets)
#   Using cached comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting ipython>=6.1.0 (from ipywidgets)
#   Downloading ipython-9.1.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting traitlets>=4.3.1 (from ipywidgets)
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.14 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl.metadata (4.1 kB)
# Collecting colorama (from ipython>=6.1.0->ipywidgets)
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator (from ipython>=6.1.0->ipywidgets)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers (from ipython>=6.1.0->ipywidgets)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython>=6.1.0->ipywidgets)
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=6.1.0->ipywidgets)
#   Downloading prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython>=6.1.0->ipywidgets)
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython>=6.1.0->ipywidgets)
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting typing_extensions>=4.6 (from ipython>=6.1.0->ipywidgets)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=6.1.0->ipywidgets)
#   Using cached parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets)
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython>=6.1.0->ipywidgets)
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=6.1.0->ipywidgets)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython>=6.1.0->ipywidgets)
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading ipywidgets-8.1.6-py3-none-any.whl (139 kB)
# Using cached comm-0.2.2-py3-none-any.whl (7.2 kB)
# Downloading ipython-9.1.0-py3-none-any.whl (604 kB)
#    ---------------------------------------- 0.0/604.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/604.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/604.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/604.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/604.1 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/604.1 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/604.1 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/604.1 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/604.1 kB ? eta -:--:--
#    ----------------- ---------------------- 262.1/604.1 kB ? eta -:--:--
#    -------------------------------- ----- 524.3/604.1 kB 236.4 kB/s eta 0:00:01
#    -------------------------------------- 604.1/604.1 kB 243.2 kB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.14-py3-none-any.whl (213 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 453.5 kB/s eta 0:00:04
#    --------- ------------------------------ 0.5/2.2 MB 453.5 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 466.0 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 466.0 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 466.0 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 466.0 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 466.0 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ------------------- -------------------- 1.0/2.2 MB 367.3 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ----------------------- ---------------- 1.3/2.2 MB 258.1 kB/s eta 0:00:04
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    ---------------------------- ----------- 1.6/2.2 MB 224.9 kB/s eta 0:00:03
#    --------------------------------- ------ 1.8/2.2 MB 204.6 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 204.6 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 204.6 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 204.6 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 204.6 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 204.6 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 204.6 kB/s eta 0:00:02
#    -------------------------------------- - 2.1/2.2 MB 199.0 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 199.0 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 199.0 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 199.0 kB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.6 MB 188.5 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.6 MB 188.5 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.6 MB 188.5 kB/s eta 0:00:06
#    ------------- -------------------------- 0.5/1.6 MB 188.5 kB/s eta 0:00:06
#    -------------------- ------------------- 0.8/1.6 MB 243.2 kB/s eta 0:00:04
#    -------------------- ------------------- 0.8/1.6 MB 243.2 kB/s eta 0:00:04
#    -------------------------- ------------- 1.0/1.6 MB 290.9 kB/s eta 0:00:02
#    -------------------------- ------------- 1.0/1.6 MB 290.9 kB/s eta 0:00:02
#    -------------------------- ------------- 1.0/1.6 MB 290.9 kB/s eta 0:00:02
#    --------------------------------- ------ 1.3/1.6 MB 322.6 kB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 322.6 kB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 322.6 kB/s eta 0:00:01
#    --------------------------------- ------ 1.3/1.6 MB 322.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 322.5 kB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    -------- ------------------------------- 0.3/1.2 MB ? eta -:--:--
#    ----------------- ---------------------- 0.5/1.2 MB 381.0 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 381.0 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.5/1.2 MB 381.0 kB/s eta 0:00:02
#    ------------------------- -------------- 0.8/1.2 MB 390.1 kB/s eta 0:00:02
#    ------------------------- -------------- 0.8/1.2 MB 390.1 kB/s eta 0:00:02
#    ------------------------- -------------- 0.8/1.2 MB 390.1 kB/s eta 0:00:02
#    ---------------------------------- ----- 1.0/1.2 MB 375.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 375.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 375.6 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.2 MB 375.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 340.6 kB/s eta 0:00:00
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Using cached parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, pure-eval, widgetsnbextension, typing_extensions, traitlets, pygments, prompt_toolkit, parso, jupyterlab_widgets, executing, decorator, colorama, asttokens, stack_data, matplotlib-inline, jedi, ipython-pygments-lexers, comm, ipython, ipywidgets
# Successfully installed asttokens-3.0.0 colorama-0.4.6 comm-0.2.2 decorator-5.2.1 executing-2.2.0 ipython-9.1.0 ipython-pygments-lexers-1.1.1 ipywidgets-8.1.6 jedi-0.19.2 jupyterlab_widgets-3.0.14 matplotlib-inline-0.1.7 parso-0.8.4 prompt_toolkit-3.0.51 pure-eval-0.2.3 pygments-2.19.1 stack_data-0.6.3 traitlets-5.14.3 typing_extensions-4.13.2 wcwidth-0.2.13 widgetsnbextension-4.0.14

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [i**2 for i in x]

plt.plot(x, y)
plt.title("Square Numbers")
plt.xlabel("x")
plt.ylabel("y^2")
plt.show()

# %% [markdown]
# # Display settings

# %%
import pandas as pd
pd.set_option("display.max_columns",None)

# %%
import sklearn
sklearn.set_config(transform_output = "default")

# %% [markdown]
# # get the data

# %%
train_df = pd.read_csv("Data/train.csv")
val_df = pd.read_csv("Data/val.csv")
test_df = pd.read_csv("Data/test.csv")

# %%
train_df
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       11:50:00        90          0.0  In-flight meal not included   4995
# 1       07:40:00      1360          1.0                      No Info   8372
# 2       11:05:00      1555          2.0                      No Info   6117
# 3       22:55:00      1595          1.0                      No Info   7770
# 4       10:45:00      1065          1.0                      No Info   9187
# ..           ...       ...          ...                          ...    ...
# 635     07:45:00       170          0.0                      No Info   4282
# 636     21:05:00       690          1.0                      No Info  13067
# 637     08:50:00       165          0.0                      No Info   4423
# 638     21:00:00       735          1.0                      No Info   7670
# 639     12:00:00       960          1.0  In-flight meal not included  10844
#
# [640 rows x 10 columns]

# %%
val_df
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0            Air India      2019-06-01     Delhi      Cochin  05:15:00
# 1            Air India      2019-03-03     Delhi      Cochin  20:00:00
# 2            Air India      2019-03-06    Mumbai   Hyderabad  05:55:00
# 3                Goair      2019-06-09   Kolkata    Banglore  16:40:00
# 4          Jet Airways      2019-06-03     Delhi      Cochin  20:55:00
# ..                 ...             ...       ...         ...       ...
# 155           Spicejet      2019-04-03     Delhi      Cochin  08:45:00
# 156           Spicejet      2019-03-01    Mumbai   Hyderabad  05:45:00
# 157  Multiple Carriers      2019-05-18     Delhi      Cochin  03:50:00
# 158        Jet Airways      2019-03-01  Banglore   New Delhi  22:50:00
# 159             Indigo      2019-04-18  Banglore       Delhi  18:25:00
#
#     arrival_time  duration  total_stops               additional_info  price
# 0       19:15:00      2280          3.0                       No Info  10703
# 1       19:15:00      1395          2.0                       No Info  17266
# 2       22:00:00       965          1.0                       No Info  10366
# 3       00:15:00       455          1.0                       No Info   9495
# 4       19:00:00      1325          1.0                       No Info  14714
# ..           ...       ...          ...                           ...    ...
# 155     13:15:00       270          1.0  No check-in baggage included   4098
# 156     07:05:00        80          0.0                       No Info  12475
# 157     12:35:00       525          1.0                       No Info  10197
# 158     00:45:00      1555          1.0                       No Info  26890
# 159     21:20:00       175          0.0                       No Info   4990
#
# [160 rows x 10 columns]

# %%
test_df
# Out:
#                airline date_of_journey   source destination  dep_time  \
# 0    Multiple Carriers      2019-03-03    Delhi      Cochin  18:15:00
# 1          Jet Airways      2019-06-01    Delhi      Cochin  20:55:00
# 2    Multiple Carriers      2019-06-06    Delhi      Cochin  07:05:00
# 3            Air India      2019-03-24  Kolkata    Banglore  16:50:00
# 4    Multiple Carriers      2019-05-27    Delhi      Cochin  10:20:00
# ..                 ...             ...      ...         ...       ...
# 195           Spicejet      2019-04-21  Kolkata    Banglore  06:55:00
# 196  Multiple Carriers      2019-06-01    Delhi      Cochin  11:40:00
# 197             Indigo      2019-03-21   Mumbai   Hyderabad  21:20:00
# 198        Jet Airways      2019-06-03    Delhi      Cochin  16:00:00
# 199             Indigo      2019-03-15   Mumbai   Hyderabad  09:10:00
#
#     arrival_time  duration  total_stops              additional_info  price
# 0       01:35:00       440          1.0                      No Info  18916
# 1       12:35:00       940          1.0  In-flight meal not included  10262
# 2       16:10:00       545          1.0                      No Info   9646
# 3       18:30:00      1540          1.0                      No Info  14641
# 4       19:00:00       520          1.0                      No Info   9794
# ..           ...       ...          ...                          ...    ...
# 195     09:30:00       155          0.0                      No Info   4174
# 196     19:15:00       455          1.0                      No Info  10261
# 197     22:45:00        85          0.0                      No Info   2227
# 198     12:35:00      1235          1.0  In-flight meal not included  10262
# 199     10:40:00        90          0.0                      No Info   4049
#
# [200 rows x 10 columns]

# %% [markdown]
# # 3.1 split the data

# %%
def split_data(data):
    X = data.drop(columns = "price")
    y = data.price.copy()
    return(X,y)

# %%
X_train,y_train = split_data(train_df)

# %%
X_train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info
# 0       11:50:00        90          0.0  In-flight meal not included
# 1       07:40:00      1360          1.0                      No Info
# 2       11:05:00      1555          2.0                      No Info
# 3       22:55:00      1595          1.0                      No Info
# 4       10:45:00      1065          1.0                      No Info
# ..           ...       ...          ...                          ...
# 635     07:45:00       170          0.0                      No Info
# 636     21:05:00       690          1.0                      No Info
# 637     08:50:00       165          0.0                      No Info
# 638     21:00:00       735          1.0                      No Info
# 639     12:00:00       960          1.0  In-flight meal not included
#
# [640 rows x 9 columns]

# %%
y_train
# Out:
# 0       4995
# 1       8372
# 2       6117
# 3       7770
# 4       9187
#        ...
# 635     4282
# 636    13067
# 637     4423
# 638     7670
# 639    10844
# Name: price, Length: 640, dtype: int64

# %%
X_val,y_val = split_data(val_df)

# %%
X_test,y_test = split_data(test_df)

# %% [markdown]
# # data preprocessing

# %%
dt_cols = ["date_of_journey","dep_time","arrival_time"]
num_cols = ["duration","total_stops"]
cat_cols = [col for col in X_train.columns if (col not in dt_cols) and (col not in num_cols)]

# %%
cat_cols
# Out:
# ['airline', 'source', 'destination', 'additional_info']

# %%
# !pip install feature-engine
# Out:
# Requirement already satisfied: feature-engine in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (1.8.3)
# Requirement already satisfied: numpy>=1.18.2 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from feature-engine) (1.25.0)
# Requirement already satisfied: pandas>=2.2.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from feature-engine) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.4.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from feature-engine) (1.6.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from feature-engine) (1.15.2)
# Requirement already satisfied: statsmodels>=0.11.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from feature-engine) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from pandas>=2.2.0->feature-engine) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from pandas>=2.2.0->feature-engine) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from pandas>=2.2.0->feature-engine) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from scikit-learn>=1.4.0->feature-engine) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from statsmodels>=0.11.1->feature-engine) (24.2)
# Requirement already satisfied: six>=1.5 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature-engine) (1.17.0)

# %%
# !pip show feature-engine
# Out:
# Name: feature-engine
# Version: 1.8.3
# Summary: Feature engineering and selection package with Scikit-learn's fit transform functionality
# Home-page: http://github.com/feature-engine/feature_engine
# Author: Soledad Galli
# Author-email: solegalli@protonmail.com
# License: BSD 3 clause
# Location: C:\Users\Atishay\anaconda3\envs\flask_ml\Lib\site-packages
# Requires: numpy, pandas, scikit-learn, scipy, statsmodels
# Required-by:

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
# !pip install ipykernel
# Out:
# Collecting ipykernel
#   Using cached ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: comm>=0.1.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipykernel) (0.2.2)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Downloading debugpy-1.8.14-cp311-cp311-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipykernel) (9.1.0)
# Collecting jupyter-client>=6.1.12 (from ipykernel)
#   Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Collecting jupyter-core!=5.0.*,>=4.12 (from ipykernel)
#   Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipykernel) (0.1.7)
# Collecting nest-asyncio (from ipykernel)
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: packaging in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipykernel) (24.2)
# Collecting psutil (from ipykernel)
#   Downloading psutil-7.0.0-cp37-abi3-win_amd64.whl.metadata (23 kB)
# Collecting pyzmq>=24 (from ipykernel)
#   Downloading pyzmq-26.4.0-cp311-cp311-win_amd64.whl.metadata (6.0 kB)
# Collecting tornado>=6.1 (from ipykernel)
#   Downloading tornado-6.4.2-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.51)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from ipython>=7.23.1->ipykernel) (4.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from jupyter-client>=6.1.12->ipykernel) (2.9.0.post0)
# Collecting platformdirs>=2.5 (from jupyter-core!=5.0.*,>=4.12->ipykernel)
#   Downloading platformdirs-4.3.7-py3-none-any.whl.metadata (11 kB)
# Collecting pywin32>=300 (from jupyter-core!=5.0.*,>=4.12->ipykernel)
#   Downloading pywin32-310-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.13)
# Requirement already satisfied: six>=1.5 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Using cached ipykernel-6.29.5-py3-none-any.whl (117 kB)
# Downloading debugpy-1.8.14-cp311-cp311-win_amd64.whl (5.2 MB)
#    ---------------------------------------- 0.0/5.2 MB ? eta -:--:--
#    ------------ --------------------------- 1.6/5.2 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------------- 5.2/5.2 MB 18.4 MB/s eta 0:00:00
# Using cached jupyter_client-8.6.3-py3-none-any.whl (106 kB)
# Using cached jupyter_core-5.7.2-py3-none-any.whl (28 kB)
# Downloading pyzmq-26.4.0-cp311-cp311-win_amd64.whl (644 kB)
#    ---------------------------------------- 0.0/644.7 kB ? eta -:--:--
#    --------------------------------------- 644.7/644.7 kB 23.9 MB/s eta 0:00:00
# Downloading tornado-6.4.2-cp38-abi3-win_amd64.whl (438 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Downloading psutil-7.0.0-cp37-abi3-win_amd64.whl (244 kB)
# Downloading platformdirs-4.3.7-py3-none-any.whl (18 kB)
# Downloading pywin32-310-cp311-cp311-win_amd64.whl (9.5 MB)
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    ------------------------- -------------- 6.0/9.5 MB 30.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 26.9 MB/s eta 0:00:00
# Installing collected packages: pywin32, tornado, pyzmq, psutil, platformdirs, nest-asyncio, debugpy, jupyter-core, jupyter-client, ipykernel
# Successfully installed debugpy-1.8.14 ipykernel-6.29.5 jupyter-client-8.6.3 jupyter-core-5.7.2 nest-asyncio-1.6.0 platformdirs-4.3.7 psutil-7.0.0 pywin32-310 pyzmq-26.4.0 tornado-6.4.2

# %%
# !python -m ipykernel install --user --name flask_ml --display-name "Python (flask_ml)"
# Out:
# Installed kernelspec flask_ml in C:\Users\Atishay\AppData\Roaming\jupyter\kernels\flask_ml

# %%
from feature_engine.datetime import DatetimeFeatures

# %%
num_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("Scaler", StandardScaler())
])

cat_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("encoder", OneHotEncoder(sparse_output=False,handle_unknown ="ignore"))
])

doj_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("extractor", DatetimeFeatures(features_to_extract=["month", "week", "day_of_week", "day_of_month"], format="mixed")),
    ("Scaler", StandardScaler())
])

time_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("extractor", DatetimeFeatures(features_to_extract=["hour", "minute"], format="mixed")),
    ("Scaler", StandardScaler())
])

# %%
preprocessor  = ColumnTransformer(transformers = [
    ("num",num_transformer,num_cols),
    ("cat",cat_transformer,cat_cols),
    ("doj",doj_transformer,["date_of_journey"]),
    ("time",time_transformer,["dep_time","arrival_time"])
])

# %%
preprocessor.fit_transform(X_train)
# Out:
# array([[-1.09591823, -1.21213152,  0.        , ..., -0.14005709,
#         -0.34523131,  1.49385907],
#        [ 1.43569944,  0.31797533,  0.        , ..., -1.22986299,
#         -0.93560684,  0.89104078],
#        [ 1.82441239,  1.84808218,  0.        , ..., -0.68496004,
#         -0.34523131, -1.21882323],
#        ...,
#        [-0.94641325, -1.21213152,  0.        , ..., -0.95741152,
#         -0.78801296,  1.49385907],
#        [ 0.18982461,  0.31797533,  0.        , ...,  1.22220029,
#          1.1307075 , -1.52023237],
#        [ 0.63833955,  0.31797533,  0.        , ..., -1.22986299,
#         -0.19763743, -1.52023237]])

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-3.0.0-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from xgboost) (1.25.0)
# Requirement already satisfied: scipy in c:\users\atishay\anaconda3\envs\flask_ml\lib\site-packages (from xgboost) (1.15.2)
# Downloading xgboost-3.0.0-py3-none-win_amd64.whl (150.0 MB)
#    ---------------------------------------- 0.0/150.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/150.0 MB 5.6 MB/s eta 0:00:27
#    - -------------------------------------- 5.2/150.0 MB 18.7 MB/s eta 0:00:08
#    -- ------------------------------------- 9.2/150.0 MB 22.0 MB/s eta 0:00:07
#    --- ------------------------------------ 14.9/150.0 MB 22.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 19.9/150.0 MB 22.5 MB/s eta 0:00:06
#    ------ --------------------------------- 25.2/150.0 MB 22.8 MB/s eta 0:00:06
#    -------- ------------------------------- 30.9/150.0 MB 23.6 MB/s eta 0:00:06
#    --------- ------------------------------ 36.7/150.0 MB 24.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 43.0/150.0 MB 25.1 MB/s eta 0:00:05
#    ------------- -------------------------- 48.8/150.0 MB 25.2 MB/s eta 0:00:05
#    -------------- ------------------------- 55.1/150.0 MB 25.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 60.6/150.0 MB 25.6 MB/s eta 0:00:04
#    ----------------- ---------------------- 67.4/150.0 MB 26.2 MB/s eta 0:00:04
#    ------------------- -------------------- 72.6/150.0 MB 26.2 MB/s eta 0:00:03
#    -------------------- ------------------- 78.6/150.0 MB 26.4 MB/s eta 0:00:03
#    ---------------------- ----------------- 84.4/150.0 MB 26.5 MB/s eta 0:00:03
#    ------------------------ --------------- 90.2/150.0 MB 26.6 MB/s eta 0:00:03
#    ------------------------- -------------- 96.2/150.0 MB 26.7 MB/s eta 0:00:03
#    -------------------------- ------------ 101.7/150.0 MB 26.8 MB/s eta 0:00:02
#    --------------------------- ----------- 106.2/150.0 MB 26.6 MB/s eta 0:00:02
#    ----------------------------- --------- 111.7/150.0 MB 26.5 MB/s eta 0:00:02
#    ------------------------------ -------- 118.2/150.0 MB 26.8 MB/s eta 0:00:02
#    -------------------------------- ------ 125.0/150.0 MB 27.0 MB/s eta 0:00:01
#    ---------------------------------- ---- 131.9/150.0 MB 27.3 MB/s eta 0:00:01
#    ----------------------------------- --- 138.1/150.0 MB 27.4 MB/s eta 0:00:01
#    ------------------------------------- - 144.4/150.0 MB 27.5 MB/s eta 0:00:01
#    --------------------------------------  149.9/150.0 MB 27.7 MB/s eta 0:00:01
#    --------------------------------------  149.9/150.0 MB 27.7 MB/s eta 0:00:01
#    --------------------------------------- 150.0/150.0 MB 25.6 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-3.0.0

# %% [markdown]
# # 5. Model Selection

# %%
from sklearn.linear_model import LinearRegression 
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor 
from sklearn.metrics import r2_score
from sklearn.model_selection import learning_curve

# %%
algorithms = {
    "Linear Regression":LinearRegression(),
    "Support Vector Machine":SVR(),
    "Random Forest":RandomForestRegressor(n_estimators =10),
    "xgboost":XGBRegressor(n_estimators =10)
}

# %%
data  = pd.concat([train_df,val_df],axis=0)
data
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 155           Spicejet      2019-04-03     Delhi      Cochin  08:45:00
# 156           Spicejet      2019-03-01    Mumbai   Hyderabad  05:45:00
# 157  Multiple Carriers      2019-05-18     Delhi      Cochin  03:50:00
# 158        Jet Airways      2019-03-01  Banglore   New Delhi  22:50:00
# 159             Indigo      2019-04-18  Banglore       Delhi  18:25:00
#
#     arrival_time  duration  total_stops               additional_info  price
# 0       11:50:00        90          0.0   In-flight meal not included   4995
# 1       07:40:00      1360          1.0                       No Info   8372
# 2       11:05:00      1555          2.0                       No Info   6117
# 3       22:55:00      1595          1.0                       No Info   7770
# 4       10:45:00      1065          1.0                       No Info   9187
# ..           ...       ...          ...                           ...    ...
# 155     13:15:00       270          1.0  No check-in baggage included   4098
# 156     07:05:00        80          0.0                       No Info  12475
# 157     12:35:00       525          1.0                       No Info  10197
# 158     00:45:00      1555          1.0                       No Info  26890
# 159     21:20:00       175          0.0                       No Info   4990
#
# [800 rows x 10 columns]

# %%
X_data , y_data = split_data(data)

# %%
def plot_curves(Sizes,mean_scores,std_scores,label,ax):
    ax.plot(
        Sizes,
        mean_scores,
        marke ='o',
        label = label
    )
    ax.fill_between(
        x = Sizes,
        y1 = mean_scores - std_scores,
        y2 = mean_scores + std_scores,
        alpha = 0.5
    )

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.pipeline import Pipeline

def plot_curves(sizes, mean_scores, std_scores, label, ax):
    ax.plot(sizes, mean_scores, label=label)
    ax.fill_between(sizes, mean_scores - std_scores, mean_scores + std_scores, alpha=0.2)

def plot_learning_curves(name, algorithm, X_data, y_data, preprocessor, figsize=(12, 4)):
    model = Pipeline(steps=[
        ("pre", preprocessor),
        ("alg", algorithm)
    ])

    train_sizes, train_scores, test_scores = learning_curve(
        estimator=model,
        X=X_data,
        y=y_data,
        cv=3,
        scoring="r2",
        n_jobs=1
    )

    mean_train_scores = np.mean(train_scores, axis=1)
    std_train_scores = np.std(train_scores, axis=1)
    train_score = f"{mean_train_scores[-1]:.2f} +/- {std_train_scores[-1]:.2f}"

    mean_test_scores = np.mean(test_scores, axis=1)
    std_test_scores = np.std(test_scores, axis=1)
    test_score = f"{mean_test_scores[-1]:.2f} +/- {std_test_scores[-1]:.2f}"

    fig, ax = plt.subplots(figsize=figsize)

    plot_curves(train_sizes, mean_train_scores, std_train_scores, f"Train ({train_score})", ax)
    plot_curves(train_sizes, mean_test_scores, std_test_scores, f"Test ({test_score})", ax)

    ax.set(xlabel="Training Set Size", ylabel="R-Square", title=name)
    ax.legend(loc="lower right")
    ax.grid(True)
    plt.show()

# %%
for name, alg in algorithms.items():
    plot_learning_curves(name, alg, X_data, y_data, preprocessor)

# %% [markdown]
# # Model Training

# %%
model  = Pipeline(steps =[
    ("pre",preprocessor),
    ("rf",RandomForestRegressor(n_estimators=10))
])

# %%
model.fit(X_data,y_data)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'total_stops']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['airline', 'source',
#                                                    '...
#                                                                                                          'day_of_month'],
#                                                                                     format='mixed')),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['date_of_journey']),
#                                                  ('time',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('extractor',
#                                                                    DatetimeFeatures(features_to_extract=['hour',
#                                                                                                          'minute'],
#                                                                                     format='mixed')),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['dep_time',
#                                                    'arrival_time'])])),
#                 ('rf', RandomForestRegressor(n_estimators=10))])

# %% [markdown]
# # 7 . Model Evaluation

# %%
def evaluate_model(X,y):
    y_pred = model.predict(X)
    return r2_score(y,y_pred)

# %%
print(f"R2 score on Training data is = {evaluate_model(X_data,y_data)}")
# Out:
# R2 score on Training data is = 0.9480637075324564

# %%
print(f"R2 score on Testing data is = {evaluate_model(X_test,y_test)}")
# Out:
# R2 score on Testing data is = 0.6952074482834648

# %% [markdown]
# # 8. Model persistance

# %%
joblib.dump(model,"model.joblib")
# Out:
# ['model.joblib']

# %%
saved_model = joblib.load("model.joblib")

# %%
saved_model
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['duration', 'total_stops']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['airline', 'source',
#                                                    '...
#                                                                                                          'day_of_month'],
#                                                                                     format='mixed')),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['date_of_journey']),
#                                                  ('time',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('extractor',
#                                                                    DatetimeFeatures(features_to_extract=['hour',
#                                                                                                          'minute'],
#                                                                                     format='mixed')),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   ['dep_time',
#                                                    'arrival_time'])])),
#                 ('rf', RandomForestRegressor(n_estimators=10))])

# %%
y_pred = saved_model.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6952074482834648
